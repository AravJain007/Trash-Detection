# %%
from ultralytics import YOLO
import cv2
import torchvision
import torch

# %%
model = YOLO('yolov8n.yaml').load('../YOLOv8n/runs/detect/train4/weights/best.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
model.train(model = 'yolov8n.yaml',data = r"..\data.yaml", cos_lr = True, epochs = 300, imgsz = 640, degrees = 20, verbose = True, batch = 4, device=0, optimizer = 'SGD', momentum = 0.95, lr0=0.1,lrf=0.001)
# Out:
# Ultralytics YOLOv8.0.123  Python-3.9.11 torch-2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3070 Ti Laptop GPU, 8192MiB)
# ...

# %%
img = r"..\test\images\IMG_0178_JPG.rf.b873cbf4e6976e8eed0d3086c171e68d.jpg"
res = model(img)
res_plotted = res[0].plot()
cv2.imshow('Hello',res_plotted)
cv2.waitKey(0)
# Out:
# image 1/1 C:\Users\get2b\Desktop\IMAGINE CUP\Dataset\test\images\IMG_0178_JPG.rf.b873cbf4e6976e8eed0d3086c171e68d.jpg: 640x640 1 foam, 6 plastic bottles, 1 plastic, 20.5ms
# Speed: 3.7ms preprocess, 20.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# -1

# %%
results = model([r"..\test\images\IMG_0178_JPG.rf.b873cbf4e6976e8eed0d3086c171e68d.jpg", 
                 r"..\test\images\IMG_0058_JPG.rf.f2c199da3574752d138b70b04b1bcbf5.jpg"])

for result in results:
    boxes = result.boxes  # Boxes object for bbox outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Class probabilities for classification outputs
# Out:
# 0: 640x640 1 foam, 6 plastic bottles, 1 plastic, 1: 640x640 7 plastic bottles, 3 unknows, 58.5ms
# Speed: 4.5ms preprocess, 29.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
